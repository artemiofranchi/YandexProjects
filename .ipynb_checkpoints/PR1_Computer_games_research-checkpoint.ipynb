# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Артем :)  Спасибо за работу, все исправления и комментарии
#
# Стоит планировать где-то 3 рабочих дня минимум на сдачу любого проекта, не меньше
#
# Стоит исправить критическую ошибку с фильтрацией данных в разделе гипотез
#
# На проекте мы изучали и практиковали навыки из разделов о/об:
#
#  + выдвижении гипотез о пропусках в данных, заполнении или удалении,
#  + работе с категориальными данными
#  + подготовке данных для решения главной задачи проекта
#  + исследовании неочищенных данных,
#  + подборе и создании графиков,
#  + программировании,
#  + автоматизации однотипных действий,
#  + выстраивании структуры проекта и обеспечении аккуратности кода,
#  + анализе данных,
#  + определении прибыльности и устойчивости продаж по выбранному параметру (жанр, платформа) на диаграмме размаха,
#  + составлении портрета пользователя,
#  + формулировании и проверке двухсторонних гипотез, <b>интерпретации значения p-value - можно повторить недели через две </b>(для профилактики :) )
#  + формировании рекомендаций для бизнеса
#
#
# <b>Поздравляю с успешно сданным сборным проектом и завершением первого модуля <br />на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />
#
# оставил комментарий про расшифровку р-значения и добавил бонус

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Артем :) Спасибо, что прислал задание :) Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://pyprog.pro/mpl/mpl_short_guide.html">Краткое руководство по Matplotlib</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %% [markdown]
# # Сборный проект 1.  Исследование компьютерных игр.
# Нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# **План выполнения работы:**
# 1. *Чтение данных*
# 2. *Подготовка данных:*
# - приведение к нижнему регистру названий столбцов.
# - обработка пропусков.
# - преобразование данных в нужные типы(с пояснениями).
# - посчёт суммарных продаж во всех регионах и запись их в отдельный столбец.
# 3. *Исследовательский анализ данных:*
# - Сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
# - Как менялись продажи по платформам. Платформы с наибольшими суммарными продажами и распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
# - Данные за соответствующий актуальный период. Актуальный период определяется самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
# - В работе данные за предыдущие годы не учитываются.
# - Какие платформы лидируют по продажам, растут или падают? Несколько потенциально прибыльных платформ.
# - График «ящик с усами» по глобальным продажам игр в разбивке по платформам. Описание результата.
# - Как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Диаграмму рассеяния и корреляция между отзывами и продажами. Выводы.
# - Сопоставление выводов с продажами игр на других платформах.
# - Общее распределение игр по жанрам. Самые прибыльные жанры. Выделяются ли жанры с высокими и низкими продажами?
# 4. *Портрет пользователя каждого региона. Для пользователя каждого региона (NA, EU, JP):*
# - Самые популярные платформы (топ-5). Различия в долях продаж.
# - Самые популярные жанры (топ-5). Пояснение разницы.
# - Влияние рейтинга ESRB на продажи в отдельном регионе.
# 5. *Проверка гипотез:*
# - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# - Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
# 6. *Общий вывод*
# **Описание данных:**
# - Name — название игры
# - Platform — платформа
# - Year_of_Release — год выпуска
# - Genre — жанр игры
# - NA_sales — продажи в Северной Америке (миллионы проданных копий)
# - EU_sales — продажи в Европе (миллионы проданных копий)
# - JP_sales — продажи в Японии (миллионы проданных копий)
# - Other_sales — продажи в других странах (миллионы проданных копий)
# - Critic_Score — оценка критиков (максимум 100)
# - User_Score — оценка пользователей (максимум 10)
# - Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
# - Данные за 2016 год могут быть неполными.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Ясная и четкая вступительная часть проекта

# %% [markdown]
# ## check

# %% [markdown]
# # 1. Чтение данных

# %%
#импортируем библиотеки
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from IPython.display import display
import math
from scipy import stats as st
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Молодец, что делишь блоки загрузки библиотек и датасета, в случае необходимости добавления новых библиотек не придется загружать весь датасет заново и перезапускать проект целиком

# %%
data = pd.read_csv('/datasets/games.csv')
data
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
display(data.info())
data.duplicated().sum() #явных дубликатов нет
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB
# None
# 0

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Проверка на поиск дубликатов выполнена, молодец
#
# Особенно это станет важным, когда мы перейдем к более сложным задачам на втором модуле курса

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# На рабочих проектах стоит искать дубликаты по ключевым столбцам, для примера по сумме параметров:
#
#     ['name', 'platform', 'year_of_release']
#
# С обязательным приведением содержимого столбцов к нижнему регистру
#
# В выборке имеется 2 строчки неполных дубликатов, если останется время стоит их поискать
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html?highlight=duplicat#pandas.DataFrame.duplicated

# %%
# df[df.duplicated(subset=['brand', ....], keep = False)]

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Не успеваю, горит дедлайн!!! Если можете подсказать как, то будет круто!

# %%
data['Rating'].value_counts()
# Out:
# E       3990
# T       2961
# M       1563
# E10+    1420
# EC         8
# RP         3
# K-A        3
# AO         1
# Name: Rating, dtype: int64

# %% [markdown]
# **Вывод:**
# - Успешно загржуены данные, в датафрейме 16715 строк, дубликатов нет.
# - Информация в столбцах соответствует названиям столбцов.
# - Тип данных в столбце Year_of_Release надо заменить на int, потому что год может быть только целым
# - Тип данных в столбце User_Score надо заменить на float, потому что оценка может быть вещественной
# - В столбцах Name, Year_of_Release, Genre, Critic_Score, User_Score и Rating есть пропуски

# %% [markdown]
# ## check

# %% [markdown]
# # 2. Подготовка данных

# %% [markdown]
# **2.1 Приведем к нижнему регистру названия столбцов.**

# %%
data.columns = data.columns.str.lower()#привели к нижнему регистру названия столбцов
data
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит привести к нижнему регистру и содержимое категориальных столбцов, в т.ч. с целью поиска дубликатов

# %% [markdown]
# **2.2 Обработка пропусков.**

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) или произошла ошибка в первой части функции ')

# %%
pass_value_barh(data)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста
#
# мой график оформлен не совсем корректно, сможешь отметить, что стоило бы исправить в графике?

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> не подписана ось иксов, наклонены надписи на оси игреков(зачем?). Можно было бы сделать сетку для наглядности.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Принимается, к вопросу сетки вернемся на втором модуле
#
# За поворот текста отвечает параметр rot, можно добавить обозначение оси х (процент записей с пропусками)
#
#         df.isna().mean()*100 — для расчета процента пропусков в колонке
#
# На графике мы оцениваем масштаб проблемы с пропусками и возможное совпадение % пропущенных значений в колонках

# %% [markdown]
# **1) name**

# %%
display(data.loc[data['name'].isna()])
#Всего 2 строки, их можно удалить.
data = data.loc[data['name'].isna() == False]
data
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# ...

# %% [markdown]
# **2) year_of_release**

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />проверим корректность алгоритма заполнения пропусков

# %%
# check
# жизненный срок платформы

years_of_life = data.pivot_table(index='platform',values='year_of_release',aggfunc=['min','max'])
years_of_life.columns=['min','max']
years_of_life['years_of_life']=years_of_life['max']-years_of_life['min']
years_of_life

# years_of_life.sort_values(by = 'years_of_life', ascending = False)
# Out:
#              min     max  years_of_life
# platform
# 2600      1980.0  1989.0            9.0
# 3DO       1994.0  1995.0            1.0
# 3DS       2011.0  2016.0            5.0
# DC        1998.0  2008.0           10.0
# DS        1985.0  2013.0           28.0
# GB        1988.0  2001.0           13.0
# GBA       2000.0  2007.0            7.0
# GC        2001.0  2007.0            6.0
# GEN       1990.0  1994.0            4.0
# GG        1992.0  1992.0            0.0
# N64       1996.0  2002.0            6.0
# NES       1983.0  1994.0           11.0
# NG        1993.0  1996.0            3.0
# PC        1985.0  2016.0           31.0
# PCFX      1996.0  1996.0            0.0
# PS        1994.0  2003.0            9.0
# PS2       2000.0  2011.0           11.0
# PS3       2006.0  2016.0           10.0
# PS4       2013.0  2016.0            3.0
# PSP       2004.0  2015.0           11.0
# PSV       2011.0  2016.0            5.0
# SAT       1994.0  1999.0            5.0
# ...

# %%
data.loc[data['year_of_release'].isna()] # 269 пропущенных значений
# Out:
#                                     name platform  year_of_release  \
# 183                      Madden NFL 2004      PS2              NaN
# 377                     FIFA Soccer 2004      PS2              NaN
# 456           LEGO Batman: The Videogame      Wii              NaN
# 475           wwe Smackdown vs. Raw 2006      PS2              NaN
# 609                       Space Invaders     2600              NaN
# ...                                  ...      ...              ...
# 16373  PDC World Championship Darts 2008      PSP              NaN
# 16405                      Freaky Flyers       GC              NaN
# 16448                          Inversion       PC              NaN
# 16458        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16522                       Virtua Quest       GC              NaN
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 183          Sports      4.26      0.26      0.01         0.71          94.0
# ...

# %% [markdown]
# Пропущено 269 значений, они могли быть утрачены в результате технического сбоя или неверной выгрузки данных.
# Теперь посмотрим, что за платформы у этих данных

# %%
print(269/16715)
display(data.loc[data['year_of_release'].isna(),'platform'].unique())
#data = data.fillna({'year_of_release': data.groupby('name')['year_of_release'].transform('first')})
#display(data.loc[data['year_of_release'].isna()]) # осталось 146 значений
#for i in data.loc[data['year_of_release'].isna(), 'name']:
#    word = ''
#    for j in i:
#        if j!=' ':
#            word += j
#        else:
#            word = ''
#    try:
#        num_word = int(word)
#        if num_word >= 2000:
#            data.loc[(data['name'] == i) & (data['year_of_release'].isna()), 'year_of_release'] = num_word
#    except:
#        word = ''
#display(data.loc[data['year_of_release'].isna()])
# Out:
# 0.01609332934489979
# array(['PS2', 'Wii', '2600', 'X360', 'GBA', 'PC', 'PS3', 'PS', 'PSP',
#        'XB', 'GB', 'DS', 'GC', '3DS', 'N64', 'PSV'], dtype=object)

# %% [markdown]
# **Всего 1.6% от всего датафрейма составляют данные, с пропущенными значением в 'year_of_release'. К тому же, платформы этих игр устаревшие(в списке нет актуальных платформ по типу PS4, XOne, WiiU). Заполним нулями, чтобы не искажать данные о сроке жизни платформ.**

# %%
data['year_of_release'] = data['year_of_release'].fillna(0)
data[data['year_of_release'].isna()].count()
# Out:
# name               0
# platform           0
# year_of_release    0
# genre              0
# na_sales           0
# eu_sales           0
# jp_sales           0
# other_sales        0
# critic_score       0
# user_score         0
# rating             0
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> не стоит за счет комментариев увеличивать ширину строки

# %%
# check
# жизненный срок платформы

# years_of_life = data.query('year_of_release > 0').pivot_table(index='platform',values='year_of_release',aggfunc=['min','max'])
# years_of_life.columns=['min','max']
# years_of_life['years_of_life']=years_of_life['max']-years_of_life['min']
# years_of_life

# years_of_life.sort_values(by = 'years_of_life', ascending = False)

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Мы внесли искажения в колонку год выпуска игры, которые приводят к ошибкам при определении срока жизни платформ
#
# Стоит посмотреть на платформы, к которым относятся пропуски, __и с легкостью расстанешься с ними ...__
#
# Рекомендуется прежде чем, выполнять проект минут 15-30 посвятить теме анализа (поиск в интернете), чтобы уверенно плавать в океане противоречивых данных :)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделано!

# %% [markdown]
# **3) genre**

# %%
data[data['genre'].isna()] # пропуски исчезли после манипуляций в первых двух пунктах
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating]
# Index: []

# %% [markdown]
# **4) critic score**

# %%
data.loc[data['critic_score'].isna()] #аж 8576 пропусков. Около 50%
# Out:
#                                 name platform  year_of_release         genre  \
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                             Tetris       GB           1989.0        Puzzle
# 9                          Duck Hunt      NES           1984.0       Shooter
# 10                        Nintendogs       DS           2005.0    Simulation
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# Пропуски могли вознинуть либо в результате утечки, либо их изначально не заполнили. К сожалению, с этими пропусками нельзя пока ничего сделать. Заполнять меданой или средним будет некорректно, потому что, на самом деле, игры могут быть сильно лучше других или наоборот сильно хуже. Даже из одинаковых жанров. Это может сильно исказить данные. Пока оставляем так.

# %% [markdown]
# **5) user_score**

# %%
data.loc[(data['user_score'].isna()) | (data['user_score'] == 'tbd')]
# Out:
#                                 name platform  year_of_release         genre  \
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                             Tetris       GB           1989.0        Puzzle
# 9                          Duck Hunt      NES           1984.0       Shooter
# 10                        Nintendogs       DS           2005.0    Simulation
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# Помним, что помимо 'NaN' есть еще 'tbd', что расшифровывается, как "to be determined". То есть оценки еще нет на момент сбора данных. Заменим на 'NaN'. Итого получится аж 9123 строки - тоже очень много для замены медианой, средним или нулями, сильно исказится правдивость.

# %%
data.loc[data['user_score'] == "tbd", 'user_score'] = np.nan

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Верно, по своей сути tbd и является Nan. Отлично, что определяешь неявные пропущенные значения.

# %% [markdown]
# **6) rating**

# %% [markdown]
# Для начала, поймем, какие значения в целом хранятся в этом столбце, и что они обозначают.

# %%
data['rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %% [markdown]
# По данным сайта ESRB:
# - E - everyone (для всех)
# - M - mature (17 лет+)
# - T - teen (13+)
# - E10+ - everyone 10+ (10+)
# - K-A - kids to adults (старое обозначение рейтинга "E")
# - AO - adults only (18+)
# - EC - early childhood (перестал использоваться, теперь обозначают "E")
# - RP - rating pending (рейтинг пока не определён)

# %% [markdown]
# То есть можно заменить K-A, EC на E, а RP на NaN

# %%
data.loc[(data['rating'] == 'EC') | (data['rating'] == 'K-A'), 'rating'] = 'E'
data.loc[data['rating'] == 'RP', 'rating'] = np.nan
display(data['rating'].unique())
data[data['rating'].isna()]
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'AO'], dtype=object)
#                                 name platform  year_of_release         genre  \
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                             Tetris       GB           1989.0        Puzzle
# 9                          Duck Hunt      NES           1984.0       Shooter
# 10                        Nintendogs       DS           2005.0    Simulation
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# ...

# %% [markdown]
# 6767 пропусков, немало. Как-то их заполнить не представляется возможным, так как не на что опираться. Данные могут сильно исказиться, если внести неправильные значения. Оставим пока так.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Рейтинг ESRB — категориальные данные, стоит внимательно взглянуть на содержимое и предложить чем заполнить пропуски, возможно это поможет найти необычные различия в поведении клиентов, допом можно подумать над сокращением количества категорий
#
# Т.к. записи с пропусками не учитываются при группировке данных, мы не сможем выявить реальный портрет клиента

# %% [markdown]
# **2.3 Преобразование данных в нужные типы.**

# %%
data['year_of_release'] = data['year_of_release'].astype('int')
data['user_score'] = pd.to_numeric(data['user_score'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16713 non-null  int64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9946 non-null   object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# **2.4 Cуммарные продажи во всех регионах в отдельном столбце**

# %%
data['total_sales'] = data[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']].sum(axis=1)
display(data)
# найдём строки с нулевыми продажами во всех регионах
data.loc[data['total_sales'] == 0] # всего 2 игры, это явно выбросы, избавимся от них
data = data.loc[data['total_sales'] > 0]
data['total_sales'].describe()
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16711               LMA Manager 2007     X360             2006        Sports
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16713               Spirits & Spells      GBA             2003      Platform
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %% [markdown]
# # Выводы:
# - Названия столбцов были приведены к нижнему регистру.
# - year_of_release заменён на int по смыслу.
# - user_score заменена на float(значения tbd заменены на np.nan, так как в данном случае оценки нет).
# - В столбце rating значения RP заменены на np.nan, так как рейтинг отсутствует
# - В столбце year_of_release пропуски по возможности заменены годом релиза той же игры на другой платформе. Или же данные взяты из самого названия игры. Остальные пропуски заменены на 0(чтобы можно было преобразовать в int).
# - В остальных столбцах пропуски оставлены как есть, так как нет возможности обработать их по имеющейся информации + к этому доля пропущенных значений около 50%(очень много)
# - В параметре rating старые значения заменены актуальными (по информации из сайта ESRB)
# - Создан столбец total_sales, в который поместили суммарные продажи

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16711 entries, 0 to 16714
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16711 non-null  object
#  1   platform         16711 non-null  object
#  2   year_of_release  16711 non-null  int64
#  3   genre            16711 non-null  object
#  4   na_sales         16711 non-null  float64
#  5   eu_sales         16711 non-null  float64
#  6   jp_sales         16711 non-null  float64
#  7   other_sales      16711 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9946 non-null   object
#  11  total_sales      16711 non-null  float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 1.7+ MB

# %% [markdown]
# ## check

# %% [markdown]
# # 3. Исследовательский анализ данных

# %% [markdown]
# **3.1 Сколько игр выпускалось в разные годы. Важны ли данные за все периоды?**

# %%
#display(data.loc[data['year_of_release'] == 2009, 'total_sales'].count())
ax = data['year_of_release'].hist(range=(1980,2017), bins=35, figsize=(10,8))
ax.set_title('Количество выпущенных игр в разные годы', fontsize=18)
ax.set_xlabel('Год выпуска',fontsize=14)
ax.set_ylabel('Количество выпущенных игр', fontsize=14)
plt.show()

# %% [markdown]
# - Видно, что до 1990 года было выпущено мало игр. Их можно принять за аномалии и не учитывать в дальнейшем.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Подписи осей на графиках и название добавят ясности и читабельности.
# Это важные элементы любой визуализации. Как добавить подписи и названия, смотри [здесь](https://pyprog.pro/mpl/mpl_axis_signatures.html) и [там](https://pyprog.pro/mpl/mpl_title.html), и
#
# [тут](https://proproprogs.ru/modules/matplotlib-razmeshchaem-standartnye-tekstovye-elementy-na-grafike?ysclid=l6agtioc6f299002507)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделано!

# %%
data = data.loc[data['year_of_release'] >= 1990]

# %% [markdown]
# **3.2 Как менялись продажи по платформам? Платформы с наибольшими суммарными продажами и распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?**

# %%
platforms_sales = data.groupby('platform')['total_sales'].agg('sum').sort_values(ascending=False)
platforms_sales_top = platforms_sales.head(23)
display(platforms_sales_top)
data_top_platforms = (data.query('platform in @platforms_sales_top.index')
                      .groupby(['platform','year_of_release'])['total_sales'].agg('sum').reset_index())

display(data_top_platforms)
sns.set(style='whitegrid')
plt.figure(figsize=(20,10))
plt.title(label='Прибыль топовых платформ по годам', fontsize=25)
sns.lineplot(x='year_of_release', y='total_sales', hue='platform', data = data_top_platforms);
# Out:
# platform
# PS2     1233.56
# X360     961.24
# PS3      931.34
# Wii      891.18
# DS       802.76
# PS       727.58
# PS4      314.14
# GBA      312.88
# PSP      289.53
# 3DS      257.81
# PC       255.69
# XB       251.57
# N64      218.01
# SNES     200.04
# GC       196.73
# GB       188.03
# XOne     159.32
# WiiU      82.19
# PSV       53.81
# SAT       33.59
# GEN       28.35
# NES       27.54
# DC        15.95
# Name: total_sales, dtype: float64
#     platform  year_of_release  total_sales
# 0        3DS             2011        63.20
# 1        3DS             2012        51.36
# 2        3DS             2013        56.57
# 3        3DS             2014        43.76
# 4        3DS             2015        27.78
# ..       ...              ...          ...
# 197       XB             2008         0.18
# 198     XOne             2013        18.96
# 199     XOne             2014        54.07
# 200     XOne             2015        60.14
# ...

# %% [markdown]
# **Из графика видно, что (исходя из количества покупок) большинство платформ(в т.ч. и самые крупные) популярны в течение 5-10 лет. Затем продажи падают и они уходят с рынка.**

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит определить характерный срок от начала до завершения продаж по крупным платформам

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Так вроде же написал - 5-10 лет 🤔

# %% [markdown]
# **3.3 Данные за актуальный период**

# %% [markdown]
# Посмотрим на актуальные платформы, то есть на которых были выпущены игры в 2015-2016 году(поскольку в 2016 данные могут быть неполными).

# %%
platforms_actual = data.loc[data['year_of_release'] >= 2015, 'platform'].unique()
display(platforms_actual)
data_top_actual = data.query('platform in @platforms_actual and platform in @data_top_platforms["platform"].unique()').reset_index(drop=True)
data_total_sales_actual = (
    data_top_actual
    .groupby(['platform','year_of_release'])['total_sales'].sum().reset_index()  
)
display(data_top_actual)
display(data_total_sales_actual)
plt.figure(figsize=(20,10))
plt.title(label='Прибыль актуальных топовых платформ', fontsize=25)
sns.lineplot(x='year_of_release', y='total_sales', hue='platform', data=data_total_sales_actual);
# Out:
# array(['PS4', 'XOne', '3DS', 'WiiU', 'PS3', 'X360', 'PC', 'Wii', 'PSV',
#        'PSP'], dtype=object)
#                                name platform  year_of_release       genre  \
# 0                        Wii Sports      Wii             2006      Sports
# 1                    Mario Kart Wii      Wii             2008      Racing
# 2                 Wii Sports Resort      Wii             2009      Sports
# 3                          Wii Play      Wii             2006        Misc
# 4         New Super Mario Bros. Wii      Wii             2009    Platform
# ...                             ...      ...              ...         ...
# 7693               Aiyoku no Eustia      PSV             2014        Misc
# 7694  Samurai Warriors: Sanada Maru      PS3             2016      Action
# 7695               LMA Manager 2007     X360             2006      Sports
# 7696        Haitaka no Psychedelica      PSV             2016   Adventure
# ...

# %% [markdown]
# **Почти все актуальные(которые и сейчас функционируют) топовые платформы появились после 2005 года(кроме ПК).**
# - Стоит отметить, что некоторые платформы однозначно устарели, потому что компании выпустили прямого преемника. А именно: Wii, PS3, X360. У них есть преемники WiiU, PS4, XOne.
# - Таким образом остается посмотреть на платформы 'PS4', '3DS', 'XOne', 'WiiU', 'PC'
# - Оставшиеся платформы(помимо пк) вышли(набрали популярность) лишь после **2010 года**. При этом вполне понятно, что нас будет интересовать информация только за последние 2-3 года, так как индустрия стремительно изменяется и действительно на прогноз будут влиять данные, начиная **с 2014 года.**

# %% [markdown]
# **Построим график за 2010-2016 год, чтобы было более информативно(если брать за 2014-2016, то картина будет слишком "узкой")**

# %%
platforms_top_actual = ['PS4', '3DS', 'XOne', 'WiiU', 'PC']
data_total_sales_actual_2010 = (
    data_total_sales_actual.query('year_of_release >= 2010 and platform in @platforms_top_actual')
    .groupby(['platform', 'year_of_release'])['total_sales'].sum().reset_index()
)
plt.figure(figsize=(20,10))
plt.title(label='Прибыль актуальных топовых платформ, начиная с 2010 года', fontsize=25)
sns.lineplot(x='year_of_release', y='total_sales', hue='platform', data=data_total_sales_actual_2010);

# %% [markdown]
# **Выводы:**
# - Будем иметь в виду, что данные за 2016 год неполные. Наверняка именно поэтому на графике такой резкий спад.
# - PS4 показывает прекрасные продажи с самого запуска платформы. Со временем продажи только растут, абсолютный лидер на рынке.
# - XOne является основным конкурентом PS4 и показывает очень хороший рост. Но по сравнению с PS4 результаты не впечатляют.
# - 3DS имел пик в 2011 году, а затем небольшой подъем в 2013 году после 2012. Но дальше в период с 2013 по 2015 стабильный спад.
# - WiiU показывает самые стабильные продажи, в 2015 году заметен небольшой спад.
# - PC платформа самая стабильная за всю историю, но она не сравнится по продажам с гигантами. В 2011 был пик в районе 30 млн, далее спад. Но стоит заметить, что за весь период игровой индустрии PC держит в среднем планку 5-10 млн.

# %% [markdown]
# **3.4 Глобальные продажи игр в разбивке по актуальным платформам**

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. Но и слишком короткий период тоже брать не стоит
#
#         data_top_actual = data_top_actual.query('platform in @platforms_actual and year_of_release >= 2010')

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделано! Взял, начиная с 2014 года.

# %% [markdown]
# **Возьмем актуальный период 2014-2016 гг. Данные старше нас интересовать не будут**

# %%
data_top_actual = data_top_actual.query('year_of_release >= 2014') 
display(platforms_actual)
data_actual = data.query('platform in @platforms_actual').reset_index(drop=True)
# уберем устаревшие платформы
display(data_actual)
plt.figure(figsize=(14,8))
sns.set(style='ticks')
plt.title('Распределение глобальных продаж по плаформам', fontsize=20)
plt.xlabel('Игровая платформа', fontsize=15)
plt.ylabel('Глобальные продажи', fontsize=15)
myboxplot = sns.boxplot(data=data_actual, y="total_sales", x='platform')
myboxplot.set(yscale="log")# нужно взять total_sales в десятичном логарифме, так как иначе будет очень ненаглядно 
plt.show()
# Out:
# array(['PS4', 'XOne', '3DS', 'WiiU', 'PS3', 'X360', 'PC', 'Wii', 'PSV',
#        'PSP'], dtype=object)
#                                name platform  year_of_release       genre  \
# 0                        Wii Sports      Wii             2006      Sports
# 1                    Mario Kart Wii      Wii             2008      Racing
# 2                 Wii Sports Resort      Wii             2009      Sports
# 3                          Wii Play      Wii             2006        Misc
# 4         New Super Mario Bros. Wii      Wii             2009    Platform
# ...                             ...      ...              ...         ...
# 7693               Aiyoku no Eustia      PSV             2014        Misc
# 7694  Samurai Warriors: Sanada Maru      PS3             2016      Action
# 7695               LMA Manager 2007     X360             2006      Sports
# 7696        Haitaka no Psychedelica      PSV             2016   Adventure
# ...

# %% [markdown]
# Посмотрим еще 100% масштаб, чтобы увидеть все выбросы

# %%
plt.figure(figsize=(14,8))
sns.set(style='ticks')
plt.title('Распределение глобальных продаж по плаформам', fontsize=20)
plt.xlabel('Игровая платформа', fontsize=15)
plt.ylabel('Глобальные продажи', fontsize=15)
myboxplot_fullscale = sns.boxplot(data=data_actual, y="total_sales", x='platform')
plt.show()

# %% [markdown]
# На графике видно, что очень много выбросов. Особенно на платформе Wii, там они самые неприятные(могут сильно исказить картину).

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Что показывают нам две диаграммы размаха — кол-во выбросов, это игры, которые принесли максимум выручки. Т.е. можно платформы/жанры сравнить по кол-ву игр-рекордсменов, а значит определить, какая из них способна выпустить наиболее привлекательные для игроманов игры. Это про выбросы
#
# Второй вид мы используем для того, чтобы сравнить медианные продажи по платформе/жанру, чтобы уточнить в каком кол-ве продаются игры на платформе/жанре, какая из них более стабильна в продажах...
#
#
# Две хорошие статьи про диаграмму размаха
#
# [Визуализация категориальных данных](https://pyprog.pro/sns/sns_7_categorical_data.html?)
#
# [Исследуем отношение между переменными](https://dfedorov.spb.ru/pandas/downey/%D0%98%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D0%B5%D0%BC%20%D0%BE%D1%82%D0%BD%D0%BE%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B5%D0%B6%D0%B4%D1%83%20%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.html?)

# %%
display(data_top_actual['total_sales'].describe())
display(data_top_actual[data_top_actual['total_sales'] > 1])
print(223/1788)
# Out:
# count    1689.000000
# mean        0.431883
# std         1.056109
# min         0.010000
# 25%         0.030000
# 50%         0.100000
# 75%         0.350000
# max        14.630000
# Name: total_sales, dtype: float64
#                                           name platform  year_of_release  \
# 11                   Call of Duty: Black Ops 3      PS4             2015
# 21                          Grand Theft Auto V      PS4             2014
# 23   Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS             2014
# 41                                     FIFA 16      PS4             2015
# 47                Star Wars Battlefront (2015)      PS4             2015
# ..                                         ...      ...              ...
# 916  The Legend of Zelda: Twilight Princess HD     WiiU             2016
# 924                                   NBA 2K17     XOne             2016
# 941                    Assassin's Creed: Rogue     X360             2014
# ...

# %% [markdown]
# - Аж 12.4% данных, больших 1, при том что третий квартиль равен 0.43. Выбросов много!
# - Медианы у платформ PS4, XOne, Wii и WiiU примерно одинаковы(~0.2)
# - У PS3 и X360 самое высокое медианное значение и относительно небольшой разброс, хотя платформы устарели. Удивительно.
# - У 3Ds и PSP поменьше, в районе 0.1, но самое маленькое медианное значение у PС и PSV.
# - PS4 и XOne одни из самых продаваемых платформ, но при этом у них самый большой разброс значений.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Отлично, ты используешь диаграмму размаха для определения успешности платформы, молодец
#
# Для более полной оценки продаж на платформах стоит добавить график со 100% масштабом, посмотреть на максимальные продажи

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Не стоит ограничивать перечень платформ из актуального периода для оценки прибыльности платформ__
#
# диаграмму размаха перерисовать на актуальной выборке с полным перечнем платформ

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделано!

# %% [markdown]
# # example 1

# %% [markdown]
# #### example 3

# %% [markdown]
# ##### example 4

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# стоит выделять разделы проекта заголовками разного уровня, за уровень отвечает количество знаков #
#
#         # example 1
#
#         #### example 3
#
#         ##### example 4

# %% [markdown]
# **3.5 Влияние на продажи внутри одной популярной платформы отзывов пользователей и критиков. Соотношение выводов с продажами на других платформах.**

# %% [markdown]
# Возьмем платформу XOne.

# %%
data_xone = data_top_actual.loc[(data_top_actual['platform'] == 'XOne')]
display(data_xone)
sns.set(style='whitegrid')
graph1 = plt.figure(figsize=(12,8))
graph1 = plt.title(label='Влияние отзывов критиков на продажи')
graph1 = sns.scatterplot(data=data_xone, x='critic_score', y='total_sales', color='red');
graph2 = plt.title(label='Влияние отзывов пользователей на продажи')
graph2 = plt.figure(figsize=(12,8))
graph2 = sns.scatterplot(data=data_xone, x='user_score', y='total_sales', color='darkblue');
#plt.show()
# Out:
#                                                name platform  year_of_release  \
# 53                        Call of Duty: Black Ops 3     XOne             2015
# 91                               Grand Theft Auto V     XOne             2014
# 96                   Call of Duty: Advanced Warfare     XOne             2014
# 125                               Halo 5: Guardians     XOne             2015
# 141                                       Fallout 4     XOne             2015
# ...                                             ...      ...              ...
# 7641                       Sébastien Loeb Rally Evo     XOne             2016
# 7650                              Rugby Challenge 3     XOne             2016
# 7652                                         ZombiU     XOne             2016
# 7665                               Prison Architect     XOne             2016
# 7671  Metal Gear Solid V: The Definitive Experience     XOne             2016
#
# ...

# %%
data_xone[['total_sales', 'critic_score','user_score']].corr() #корреляция
# Out:
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.428677   -0.070384
# critic_score     0.428677      1.000000    0.440977
# user_score      -0.070384      0.440977    1.000000

# %% [markdown]
# - Между глобальными продажами игр на платформе XOne и отзывами критиков есть небольшая корреляция. Коэффициент 0.41
# - Между глобальными продажами игр на XOne и отзывами пользователей корреляции не наблюдается. Коэффициент -0.06 подтверждает это.

# %% [markdown]
# Теперь давайте найдем коэффициенты корреляции на других платформах

# %%
(data_top_actual
 .groupby(['platform'])
 [['total_sales','critic_score','user_score']]
 .agg('corr')
 .reset_index().query('level_1 == "total_sales"')
)
# Out:
#    platform      level_1  total_sales  critic_score  user_score
# 0       3DS  total_sales          1.0      0.314117    0.215193
# 3        PC  total_sales          1.0      0.174634   -0.071597
# 6       PS3  total_sales          1.0      0.446575   -0.166761
# 9       PS4  total_sales          1.0      0.402661   -0.040132
# 12      PSP  total_sales          1.0           NaN         NaN
# 15      PSV  total_sales          1.0      0.042665   -0.168455
# 18      Wii  total_sales          1.0           NaN    1.000000
# 21     WiiU  total_sales          1.0      0.370201    0.407926
# 24     X360  total_sales          1.0      0.525723   -0.138445
# 27     XOne  total_sales          1.0      0.428677   -0.070384

# %% [markdown]
# - Наблюдается небольшая корреляция между отзывами критиков и глобальными продажами(коэфф. корреляции от 0.33 до 0.41)
# - На платформе WiiU также есть корреляция между пользовательскими оценками и глобальными продажами (коэфф. корреляции 0.4)
# - На платформе 3DS есть маленькая корреляци между пользовательскими оценками и глобальными продажами (коэфф. корреляции 0.22)
# - На остальных платформах корреляции между пользовательскиими оценками и глобальными продажами нет

# %% [markdown]
# **Вывод: на основе имеющихся данных сложно сделать однозначный вывод по поводу связи между продажами и мнениями критиков и  пользователей. Возможно, что мнение критиков ценится игроками больше, чем мнение других игроков(исключение платфома WiiU), но из-за ограниченности количетсва данных мы не можем с уверенностью это подтвердить.**

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Сравнение показателей на нескольких платформах, позволяет набрать вес твоему исследованию, молодец

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Возможно пользователи более критичны к играм, чем критики, но мы не сможем оценить какие действия повлияли на рост продаж в рамках нашего проекта (ограниченность имеющихся данных)
#
#
# __Достаточно много игр с высокой оценкой критиков и слабой выручкой__
#
# Приведу пример ложной корреляции, весьма известный в статистической литературе. Была исследована корреляционная связь между числом аистов, свивших гнезда в южных районах Швеции, и рождаемостью в эти же годы в Швеции. Расчёты, выполненные ради шутки, показали существенную положительную корреляцию между этими явлениями, хотя любому понятно, что это ложная корреляция.
#
# Ещё пример ложной корреляции между приемом на работу новых менеджеров и созданием новых производственных мощностей. Возможно, именно менеджеры являются «причиной» капиталовложений в новые производственные мощности? Или же, наоборот, создание новых производственных мощностей послужило «причиной» приема на работу новых менеджеров?
#
# Например, можно обнаружить сильную положительную связь (корреляцию) между разрушениями, вызванными пожаром, и числом пожарных, тушивших пожар. Следует ли заключить, что пожарные вызывают разрушения? Конечно, наиболее вероятное объяснение этой корреляции состоит в том, что размер пожара (внешняя переменная, которую забыли включить в исследование) оказывает влияние, как на масштаб разрушений, так и на числе привлеченных пожарных (т. е. чем больше пожар, тем большее количество пожарных вызывается на его тушение) .

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделано!

# %% [markdown]
# **3.6 Общее распределение игр по жанрам. Самые прибыльные жанры. Выделяются ли жанры с высокими и низкими продажами?**

# %%
plt.figure(figsize=(14,8))
sns.set(style="ticks")
graph = sns.boxplot(data=data_top_actual, y="total_sales", x='genre')
graph.set_title('Распределение глобальных продаж по жанрам', fontsize=20)
graph.set_xlabel('Жанр игры', fontsize=15)
graph.set_ylabel('Глобальные продажи', fontsize=15)
graph.set(yscale="log")
plt.show()

# %% [markdown]
# - Жанр 'Shooter' самый прибыльный, медианное значение ~0.38. Очень выделяется!
# - 'Platform', 'Sports' и 'Role-Playing' медианное значение ~0.21 млн копий тоже хорошо продаваемы
# - Хуже всего дела обстоят с жанрами 'Adventure', 'Strategy', 'Puzzle' ~0.07 медианное значение. Тоже выделяются довольно явно.
# - У остальных медиана колеблется от 0.1 до 0.2

# %% [markdown]
# ## check

# %% [markdown]
# # 4. Портрет пользователя каждого региона

# %% [markdown]
# Определим для пользователя каждого региона (NA, EU, JP):
# - 4.1 Самые популярные платформы (топ-5). Опишем различия в долях продаж.
# - 4.2 Самые популярные жанры (топ-5). Поясним разницу.
# - 4.3 Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %% [markdown]
# **4.1 Самые популярные платформы**

# %%
popular_platform = (data.loc[data['year_of_release'] >= 2014]
                    .pivot_table(index='platform', values=['na_sales', 'eu_sales', 'jp_sales'], aggfunc={'sum'}).reset_index()
                   )                                                           
popular_platform.columns=['platform', 'eu_sales', 'jp_sales', 'na_sales']
for i in ['eu_sales', 'jp_sales', 'na_sales']:
    popular_platform[i] = round(popular_platform[i] / sum(popular_platform[i]),3)
display(popular_platform)
# Out:
#   platform  eu_sales  jp_sales  na_sales
# 0      3DS     0.060     0.475     0.080
# 1       PC     0.066     0.000     0.025
# 2      PS3     0.094     0.121     0.078
# 3      PS4     0.480     0.161     0.347
# 4      PSP     0.000     0.004     0.000
# 5      PSV     0.013     0.156     0.009
# 6      Wii     0.010     0.000     0.007
# 7     WiiU     0.049     0.079     0.068
# 8     X360     0.057     0.001     0.100
# 9     XOne     0.171     0.003     0.286

# %%
jp_sales = popular_platform.pivot_table(index='platform', values='jp_sales').sort_values(by='jp_sales').reset_index()
jp_top5 = jp_sales['jp_sales'].iloc[4]
jp_sales['platform'] = jp_sales['platform'].where(jp_sales['jp_sales'] > jp_top5 , 'Other')
jp_sales = jp_sales.groupby('platform').sum().sort_values(by='jp_sales').reset_index()

# %%
eu_sales = popular_platform.pivot_table(index='platform', values='eu_sales').sort_values(by='eu_sales').reset_index()
eu_top5 = eu_sales['eu_sales'].iloc[4]
eu_sales['platform'] = eu_sales['platform'].where(eu_sales['eu_sales'] > eu_top5 , 'Other')
eu_sales = eu_sales.groupby('platform').sum().sort_values(by='eu_sales').reset_index()

# %%
na_sales = popular_platform.pivot_table(index='platform', values='na_sales').sort_values(by='na_sales').reset_index()
na_top5 = na_sales['na_sales'].iloc[4]
na_sales['platform'] = na_sales['platform'].where(na_sales['na_sales'] > na_top5 , 'Other')
na_sales = na_sales.groupby('platform').sum().sort_values(by='na_sales').reset_index()

# %%
pies = plt.figure(figsize=(16,8))
pies.suptitle('Самые популярные платформы в различных регионах', fontsize=25, y=0.9)
graph1 = plt.subplot(131)
graph1.set_title('Популярность платформ в Европе', fontsize=12)
graph1 = plt.pie(eu_sales['eu_sales'], labels=eu_sales['platform'], normalize=True, autopct='%.1f%%')
graph2 = plt.subplot(132)
graph2.set_title('Популярность платформ в Японии', fontsize=12)
graph2 = plt.pie(jp_sales['jp_sales'], labels=jp_sales['platform'], normalize=True, autopct='%.1f%%')
graph3 = plt.subplot(133)
graph3.set_title('Популярность платформ в Северной Америке', fontsize=12)
graph3 = plt.pie(na_sales['na_sales'], labels=na_sales['platform'], normalize=True, autopct='%.1f%%')

# %% [markdown]
# - Для Европы и Северной Америки схожие платформы в топ-5. Разные поколения PS И Xbox, а также Wii.
# - В Японии также популярны PSP, DS И PSV, чего нет в топе в Европе и Америке
# - Скорее всего в Японии под эти платформы выпускают эксклюзивные игры, поэтому они и популярны.

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Портреты клиентов нарисованы, молодец, значительное влияние на портрет оказывает период с 2010 г. ..., можем совершить ошибку при формировании рекомендации маркетологам
#
# Стоит оформить графики раздела TOП-5:
#
# + выбрать актуальный период;
# + при анализе платформ и жанров стоит все, что не вошло в ТОП-5, объединять в категорию "другие" - так картина анализа будет более полной
#
#
# Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе
#
# https://proproprogs.ru/modules/matplotlib-otobrazhenie-neskolkih-koordinatnyh-osey-v-odnom-okne

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделано!

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Отлично, молодец
#
#         осталось для жанров также выделить ТОП-5 + кат. Другие

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> пример графиков
#
# ![image.png](attachment:image.png)
#
#
# __Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе__

# %% [markdown]
# **4.2 Самые популярные жанры**

# %%
popular_genre = (data.loc[data['year_of_release'] >= 2010]
                    .pivot_table(index='genre', values=['na_sales', 'eu_sales', 'jp_sales'], aggfunc={'sum'}).reset_index()
                   )                                                           
popular_genre.columns=['genre', 'eu_sales', 'jp_sales', 'na_sales']
for i in ['eu_sales', 'jp_sales', 'na_sales']:
    popular_genre[i] = round(popular_genre[i] / sum(popular_genre[i]),2)
display(popular_genre)
display(popular_genre.sort_values(by='eu_sales', ascending=False).head()) #топ-5 для Европы
display(popular_genre.sort_values(by='jp_sales', ascending=False).head()) #топ-5 для Японии
display(popular_genre.sort_values(by='na_sales', ascending=False).head()) #топ-5 для Северной Америки
pies = plt.figure(figsize=(16,8))
pies.suptitle('Самые популярные жанры в различных регионах', fontsize=25)
graph1 = plt.subplot(131)
graph1.set_title('Европа', fontsize=16)
graph1 = plt.pie(popular_genre['eu_sales'], labels=popular_genre['genre'], normalize=True)
graph2 = plt.subplot(132)
graph2.set_title('Япония', fontsize=16)
graph2 = plt.pie(popular_genre['jp_sales'], labels=popular_genre['genre'], normalize=True)
graph3 = plt.subplot(133)
graph3.set_title('Америка', fontsize=16)
graph3 = plt.pie(popular_genre['na_sales'], labels=popular_genre['genre'], normalize=True)
# Out:
#            genre  eu_sales  jp_sales  na_sales
# 0         Action      0.28      0.24      0.26
# 1      Adventure      0.02      0.05      0.02
# 2       Fighting      0.02      0.05      0.03
# 3           Misc      0.08      0.08      0.11
# 4       Platform      0.05      0.05      0.05
# 5         Puzzle      0.01      0.01      0.01
# 6         Racing      0.07      0.02      0.04
# 7   Role-Playing      0.09      0.34      0.10
# 8        Shooter      0.20      0.05      0.21
# 9     Simulation      0.03      0.04      0.02
# 10        Sports      0.14      0.05      0.14
# 11      Strategy      0.01      0.02      0.01
#            genre  eu_sales  jp_sales  na_sales
# 0         Action      0.28      0.24      0.26
# 8        Shooter      0.20      0.05      0.21
# 10        Sports      0.14      0.05      0.14
# 7   Role-Playing      0.09      0.34      0.10
# 3           Misc      0.08      0.08      0.11
#           genre  eu_sales  jp_sales  na_sales
# ...

# %% [markdown]
# - Во всех трех регионах популярен жанр 'Action'
# - Также в топ-5 везде есть жанр 'Role-Playing' и 'Misc'
# - Японцы опять выделились: жанры 'Adventure' и 'Fighting' в Америке и Европе не настолько популярны. У последних больше популярные жанры 'Sports' и 'Shooter'

# %% [markdown]
# **4.3 Влияет ли рейтинг ESRB на продажи в отдельном регионе?**

# %%
popular_rating = (data.loc[data['year_of_release'] >= 2010]
                    .pivot_table(index='rating', values=['na_sales', 'eu_sales', 'jp_sales'], aggfunc={'sum'}).reset_index()
                   )                                                           
popular_rating.columns=['rating', 'eu_sales', 'jp_sales', 'na_sales']
for i in ['eu_sales', 'jp_sales', 'na_sales']:
    popular_rating[i] = round(popular_rating[i] / sum(popular_rating[i]),2)
display(popular_rating)
display(popular_rating.sort_values(by='eu_sales', ascending=False).head()) #топ-5 для Европы
display(popular_rating.sort_values(by='jp_sales', ascending=False).head()) #топ-5 для Японии
display(popular_rating.sort_values(by='na_sales', ascending=False).head()) #топ-5 для Северной Америки
pies = plt.figure(figsize=(16,8))
pies.suptitle('Самые популярные рейтинги в различных регионах', fontsize=25)
graph1 = plt.subplot(131)
graph1.set_title('Европа', fontsize=16)
graph1 = plt.pie(popular_rating['eu_sales'], labels=popular_rating['rating'], normalize=True)
graph2 = plt.subplot(132)
graph2.set_title('Япония', fontsize=16)
graph2 = plt.pie(popular_rating['jp_sales'], labels=popular_rating['rating'], normalize=True)
graph3 = plt.subplot(133)
graph3.set_title('Америка', fontsize=16)
graph3 = plt.pie(popular_rating['na_sales'], labels=popular_rating['rating'], normalize=True)
# Out:
#   rating  eu_sales  jp_sales  na_sales
# 0      E      0.28      0.36      0.28
# 1   E10+      0.14      0.10      0.16
# 2      M      0.42      0.23      0.39
# 3      T      0.16      0.32      0.16
#   rating  eu_sales  jp_sales  na_sales
# 2      M      0.42      0.23      0.39
# 0      E      0.28      0.36      0.28
# 3      T      0.16      0.32      0.16
# 1   E10+      0.14      0.10      0.16
#   rating  eu_sales  jp_sales  na_sales
# 0      E      0.28      0.36      0.28
# 3      T      0.16      0.32      0.16
# 2      M      0.42      0.23      0.39
# 1   E10+      0.14      0.10      0.16
#   rating  eu_sales  jp_sales  na_sales
# 2      M      0.42      0.23      0.39
# 0      E      0.28      0.36      0.28
# 1   E10+      0.14      0.10      0.16
# 3      T      0.16      0.32      0.16

# %% [markdown]
# - По рейтингу ESRB Северная Америка и Европа почти идентичны Большинство игр покупают с рейтингом 'M' (17+) и 'Е' (без ограничений). Реже для 'E10+' и 'T'.
# - В Японии все иначе. Большинство игр покупают для детей и подростков (категории 'E' и 'T'). Игры для взрослой ктаегории покупаются реже. Доля 'E10+' небольшая, аналогично Америке и Европе.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# При твоем способе подсчета игры без рейтинга оказываются полностью исключенными из анализа. Но продажи именно этих игр могут указать на ключевое различие в регионах
#
# Стоит поработать со столбцом рейтингов, заменить пропуски, посмотреть на частотность использования всех категорий рейтинга

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Не успеваю(( Не могли бы показать как?

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Иногда пропуск сам по себе является ценной информацией. Для каких стран создавалась система ESRB? Будут ли стараться авторы игр для локального рынка других стран получить рейтинг ESRB?
#
# На данном проекте стоит использовать категорию «неизвестный рейтинг» ...

# %% [markdown]
# ## check

# %% [markdown]
# # 5. Проверка гипотез

# %% [markdown]
# - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# - Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные

# %% [markdown]
# Уберем выбросы: игры с рейтнгом 3 и ниже

# %%
display(data.loc[data['user_score'].isna() == False, 'user_score'].count())
display(data.loc[data['user_score'] <= 3, 'user_score'].count())
print(164/7541) #2% выбросов, исключим
data = data.loc[data['user_score'] > 3]
# Out:
# 7461
# 162
# 0.021747778809176502

# %%
# chekc

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7299 entries, 0 to 16705
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             7299 non-null   object
#  1   platform         7299 non-null   object
#  2   year_of_release  7299 non-null   int64
#  3   genre            7299 non-null   object
#  4   na_sales         7299 non-null   float64
#  5   eu_sales         7299 non-null   float64
#  6   jp_sales         7299 non-null   float64
#  7   other_sales      7299 non-null   float64
#  8   critic_score     6773 non-null   float64
#  9   user_score       7299 non-null   float64
#  10  rating           7215 non-null   object
#  11  total_sales      7299 non-null   float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 741.3+ KB

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит поправить фильтрацию, мы удалили большую часть данных
#
#         data = data.loc[data['user_score'] <= 3]

# %% [markdown]
# **5.1**
# 1. Гипотеза H0: **"Cредние пользовательские рейтинги платформ Xbox One и PC одинаковые"**
# 2. Гипотеза H1: "Средняя пользовательская оценка игр на платформе Xbox One не равна средней пользовательской оценке игр на платформе PC"
# 3. alpha = 0.05
# 4. Будем пользоваться  специальным методом для проверки гипотезы о равенстве среднего двух генеральных совокупностей (scipy.stats.ttest_ind (array1, array2, equal_var)) - критерий Стюдента

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Гипотезы сформулированы верно

# %% [markdown]
# Учтем, что XOne появилась в 2013 году.

# %%
data_xone = data.loc[(data['platform'] == 'XOne') & (data['user_score'].isna() == False) 
                     & (data['year_of_release'] >= 2013), 'user_score']
data_pc = data.loc[(data['platform'] == 'PC') & (data['user_score'].isna() == False)
                   & (data['year_of_release'] >= 2013), 'user_score']
display(data_xone)
display(data_pc)
#сделали соответствующие срезы
# Out:
# 165      7.9
# 179      5.4
# 242      6.4
# 270      6.2
# 373      4.1
#         ...
# 16544    6.8
# 16597    6.0
# 16630    8.2
# 16643    6.6
# 16660    6.7
# Name: user_score, Length: 179, dtype: float64
# 458      3.9
# 1095     7.9
# 1437     6.0
# 1530     5.4
# 1730     7.9
#         ...
# 16453    7.1
# 16456    8.3
# 16463    6.8
# 16509    7.9
# 16692    7.6
# Name: user_score, Length: 146, dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Важно удалить пропуски и «заглушки» перед проведением теста, молодец

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит выравнивать периоды использования платформ, одна из приставок вышла на рынок совсем недавно ...

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделано!

# %% [markdown]
# Для корректной работы t-теста необходимо:
# - **Выборочные средние должны быть нормально распределены.** Благодаря ЦПТ, если размер выборки составляет хотя бы несколько десятков значений, выборочные средние, которые можно получить из одной и той же генеральной совокупности, будут распределены нормально вокруг истинного среднего этой совокупности.
# - **Дисперсии рассматриваемых генеральных совокупностей должны быть равны.** Условие коварное: если по какой-то причине выборки у нас разного размера или есть сомнения, что дисперсии у совокупностей одинаковые, стоит указать параметр equal_var как False, и тест посчитает дисперсии выборок по отдельности.

# %%
alpha = .05# задайте уровень стат. значимости

result1 = st.ttest_ind(data_xone, data_pc, equal_var=False)# проведите стат. тест о равенстве времени, которое проводят на сайте обе группы

print('p-значение:', result1.pvalue)

if result1.pvalue < alpha:# сравните p-значение с alpha
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 0.604313849573787
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# - p-value равен 0.6 > alpha.
# - p-value— вероятность при верной нулевой гипотезе получить наблюдаемое значение или более удалённое от того, которое предположили в H0
# - Уровень статистической значимости выбирается перед проведением статистического теста, а p-value — вероятность, которая вычисляется для конкретного эксперимента, то есть для уже взятой выборки. Если p-value меньше выбранного уровня статистической значимости, то нулевая гипотеза отвергается в пользу альтернативной — такой результат ещё называется значимым. А если больше, то не отвергается.
# - Значит, что **нет оснований отвергать нулевую гипотезу.**

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Что означает на языке статистики p-значение: 0.26981699425706784

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделано!

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Приведу пример и теорию для понимания формулировок и интерпретации итогов проведения гипотез</b>
#
#
# Задача. Приведены два датасета: сумма покупок, совершённых за месяц посетителями, привлечёнными по двум разным каналам. В вашем распоряжении случайная выборка из 30 покупок для каждого канала.
#
# H0 - средние чеки равны
#
#
# H1 - средние чеки НЕ равны
#
# Да сама формулировка нулевой и альтернативной гипотезы звучит именно так, но результат теста интерпретируется другими словами
#
#
# <b>Из теории на тренажере</b>
#
# Формулирование двусторонних гипотез. <br>
#
# <b>Никакие экспериментально полученные данные никогда не подтвердят какую-либо гипотезу. Это наше фундаментальное ограничение. </b>Данные могут лишь не противоречить ей или, наоборот, показывать крайне маловероятные результаты (при условии, что гипотеза верна). Но и в том, и в другом случае нет оснований утверждать, что выдвинутая гипотеза доказана.
# Допустим, данные гипотезе не противоречат, тогда мы её не отвергаем. Если же мы приходим к выводу, что получить такие данные в рамках этой гипотезы вряд ли возможно, у нас появляется основание отбросить эту гипотезу.
#
# P-значение (англ. P-value) — величина, используемая при тестировании статистических гипотез. <b>Фактически это вероятность ошибки при отклонении нулевой гипотезы (ошибки первого рода)</b> пример ниже

# %%
# Приведены два датасета: сумма покупок, совершённых за месяц посетителями ...

sample_1 = [3071, 3636, 3454, 3151, 2185, 3259, 1727, 2263, 2015,
2582, 4815, 633, 3186, 887, 2028, 3589, 2564, 1422, 1785,
3180, 1770, 2716, 2546, 1848, 4644, 3134, 475, 2686,
1838, 3352]
sample_2 = [1211, 1228, 2157, 3699, 600, 1898, 1688, 1420, 5048, 3007,
509, 3777, 5583, 3949, 121, 1674, 4300, 1338, 3066,
3562, 1010, 2311, 462, 863, 2021, 528, 1849, 255,
1740, 2596]
alpha = .05 # критический уровень статистической значимости
# если p-value окажется меньше него - отвергнем гипотезу
results = st.ttest_ind(
sample_1,
sample_2)
print('p-значение:', results.pvalue)
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:

    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.1912450522572209
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Интерпретация результата:
#
# Полученное значение p-value говорит о том, что хотя средний чек пришедших из разных каналов и неодинаков, <b>с вероятностью в почти 19% такое или большее различие можно получить случайно. </b>Это явно слишком большая вероятность, чтобы делать вывод о значимом различии между средними чеками.
#
# А если p-value  будет равно 0,9999, то это значит, что с вероятностью почти 100% <u>такое различие</u> можно получить случайно — то есть почти никогда :)  (но учитываем, что тест проводится на выборке из генеральной совокупности, все может поменяться)

# %% [markdown]
# **5.2**
# 1. Гипотеза H0: "Средняя пользовательская оценка жанра Action равна средней пользовательской оценке жанра Sports"
# 2. Гипотеза H1: **"Средняя пользовательская оценка жанра Action  не равна средней пользовательской оценке жанра Sports"**
# 3. alpha = 0.05
# 4. Будем пользоваться  специальным методом для проверки гипотезы о равенстве среднего двух генеральных совокупностей (scipy.stats.ttest_ind (array1, array2, equal_var)) - критерий Стюдента

# %% [markdown]
# **Важно отметить, что нас будет интересовать альтернативная гипотеза H1, а именно "Средние пользовательская оценка жанра Action не равна средней пользовательской оценке жанра Sports". То есть если будут основания отвергнуть нулевую гипотезу, то не будет оснований отвергнуть альтернативную**

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Нулевая и альтернативная гипотезы сформулированы некорректно
#
#         Гипотеза H0: "Средние пользовательские рейтинги жанров Action и Sports разные"
#         Гипотеза H1: "Средняя пользовательская оценка игр на жанров Action и Sports одинаковы"

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделано!

# %%
data_action = data.loc[((data['genre'] == 'Action') & (data['user_score'].isna() == False)), 'user_score']
#display(data_action)
data_sports = data.loc[((data['genre'] == 'Sports') & (data['user_score'].isna() == False)), 'user_score']
#display(data_sports)

# %%
alpha = .05

result2 = st.ttest_ind(data_action, data_sports, equal_var=False)

print('p-значение:', result2.pvalue)

if result2.pvalue < alpha:# сравните p-значение с alpha
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 0.3881776106252607
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# - p-value = 0.38 > alpha. Нулевую гипотезу не получилось опровергнуть.
# - p-value— вероятность при верной нулевой гипотезе получить наблюдаемое значение или более удалённое от того, которое предположили в H0
# - Уровень статистической значимости выбирается перед проведением статистического теста, а p-value — вероятность, которая вычисляется для конкретного эксперимента, то есть для уже взятой выборки. Если p-value меньше выбранного уровня статистической значимости, то нулевая гипотеза отвергается в пользу альтернативной — такой результат ещё называется значимым. А если больше, то не отвергается.
# - Значит, что **нет оснований отвергать нулевую гипотезу.**

# %% [markdown]
# 5.1.
# - Полученные данные не противоречат гипотезе H0: - "Средняя пользовательская оценка игр на платформе Xbox One равна средней пользовательской оценке игр на платформе PC".
# - Нет оснований отвергать нулевую гипотезу.
#
# 5.2.
# - Полученные данные не позволяют отвергнуть нулевую гипотезу "Средняя пользовательская оценка жанра Action равна средней пользовательской оценке жанра Sports".
# - Значит нет оснований отвергать нулевую гипотезу в пользу проверяемой нами альтернативной гипотезы "Средняя пользовательская оценка жанра Action не равна средней пользовательской оценке жанра Sports".

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Можно подправить некоторые моменты во всех разделах проекта
#
#         Изначальная гипотеза оказалась верна.
#
# <b>Из теории на тренажере</b>
#
# Формулирование двусторонних гипотез. <br>
#
# <b>Никакие экспериментально полученные данные никогда не подтвердят какую-либо гипотезу. Это наше фундаментальное ограничение. </b>Данные могут лишь не противоречить ей или, наоборот, показывать крайне маловероятные результаты (при условии, что гипотеза верна). Но и в том, и в другом случае нет оснований утверждать, что выдвинутая гипотеза доказана.
# Допустим, данные гипотезе не противоречат, тогда мы её не отвергаем. Если же мы приходим к выводу, что получить такие данные в рамках этой гипотезы вряд ли возможно, у нас появляется основание отбросить эту гипотезу.
#
# https://allatambov.github.io/psms/pdf/hypo-test.pdf

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделано!

# %% [markdown]
# ## check

# %% [markdown]
# # 6. Выводы:
#
# - Шаг 1.
#     - Успешно загржуены данные, в датафрейме 16715 строк, дубликатов нет.
#     - Информация в столбцах соответствует названиям столбцов.
#     - Тип данных в столбце Year_of_Release надо заменить на int, потому что год может быть только целым
#     - Тип данных в столбце User_Score надо заменить на float, потому что оценка может быть вещественной
#     - В столбцах Name, Year_of_Release, Genre, Critic_Score, User_Score и Rating есть пропуски
# - Шаг 2.
#     - Названия столбцов были приведены к нижнему регистру.
#     - year_of_release заменён на int по смыслу.
#     - user_score заменена на float(значения tbd заменены на np.nan, так как в данном случае оценки нет).
#     - В столбце rating значения RP заменены на np.nan, так как рейтинг отсутствует
#     - Всего 1.6% от всего датафрейма составляют данные, с пропущенными значением в 'year_of_release'. К тому же, платформы этих игр устаревшие(в списке нет актуальных платформ по типу PS4, XOne, WiiU). Заполним нулями, чтобы не искажать данные о сроке жизни платформ.
#     - В остальных столбцах пропуски оставлены как есть, так как нет возможности обработать их по имеющейся информации + к этому доля пропущенных значений около 50%(очень много)
#     - В параметре rating старые значения заменены актуальными (по информации из сайта ESRB)
#     - Создан столбец total_sales, в который поместили суммарные продажи
# - Шаг 3.
#     - До 1990 года было выпущено мало игр. Их можно принять за аномалии и не учитывать в дальнейшем.
#     - Большинство платформ "продается" в течение 5-10 лет, затем прибыль сильно проседает и платформа уходит на покой. Исключение ПК :)
#     - Некоторые платформы однозначно устарели, потому что компании выпустили прямого преемника. А именно: Wii, PS3, X360. У них есть преемники WiiU, PS4, XOne.
#     - Актуальный период 2014-2016 гг. Данные за эти три года помогут понять, что будет дальше, потому что индустрия очень динамичная и быстро развивается, брать более ранние промежутки времени смысла нет.
#     - В 2016 году данные неполные, держим это в голове
#     - PS4 показывает прекрасные продажи с самого запуска платформы. Со временем продажи только растут, абсолютный лидер на рынке.
#     - XOne является основным конкурентом PS4 и показывает очень хороший рост. Но по сравнению с PS4 результаты не впечатляют.
#     - 3DS имел пик в 2011 году, а затем небольшой подъем в 2013 году после 2012. Но дальше в период с 2013 по 2015 стабильный спад.
#     - WiiU показывает самые стабильные продажи, в 2015 году заметен небольшой спад.
#     - PC платформа самая стабильная за всю историю, но она не сравнится по продажам с гигантами. В 2011 был пик в районе 30 млн, далее спад. Но стоит заметить, что за весь период игровой индустрии PC держит в среднем планку 5-10 млн.
#     - Медианы глобальных продаж платформ PS4, XOne, Wii и WiiU примерно одинаковы(~0.2)
#     - У PS3 и X360 самое высокое медианное значение глобальных продаж и относительно небольшой разброс, хотя платформы устарели. Удивительно.
#     - У 3Ds и PSP медиана глобальных продаж поменьше, в районе 0.1, но самое маленькое медианное значение у PС и PSV.
#     - PS4 и XOne одни из самых продаваемых платформ, но при этом у них самый большой разброс глобальных продаж
#     - Очень много выбросов(по меньшей мере 12%)
#     - на основе имеющихся данных сложно сделать однозначный вывод по поводу связи между продажами и мнениями критиков и пользователей. Возможно, что мнение критиков ценится игроками больше, чем мнение других игроков(исключение платфома WiiU), но из-за ограниченности количетсва данных мы не можем с уверенностью это подтвердить.
#     - Наблюдается небольшая корреляция между отзывами критиков и глобальными продажами(коэфф. корреляции от 0.33 до 0.41)
#     - На платформе WiiU также есть корреляция между пользовательскими оценками и глобальными продажами (коэфф. корреляции 0.4)
#     - На платформе 3DS есть маленькая корреляци между пользовательскими оценками и глобальными продажами (коэфф. корреляции 0.22)
#     - На остальных платформах корреляции между пользовательскиими оценками и глобальными продажами нет
#     - Жанр 'Shooter' самый прибыльный, медианное значение глобальных продаж ~0.38. Очень выделяется!
# - Шаг 4
#     - Для Европы и Северной Америки схожие платформы в топ-5. Разные поколения PS И Xbox, а также Wii.
#     - В Японии также популярны PSP, DS И PSV, чего нет в топе в Европе и Америке. Скорее всего в Японии под эти платформы выпускают эксклюзивные игры, поэтому они и популярны.
#     - Во всех трех регионах популярен жанр 'Action'
#     - Также в топ-5 везде есть жанр 'Role-Playing' и 'Misc'
#     - Японцы опять выделились: жанры 'Adventure' и 'Fighting' в Америке и Европе не настолько популярны. У последних больше популярные жанры 'Sports' и 'Shooter'
#     - По рейтингу ESRB Северная Америка и Европа почти идентичны Большинство игр покупают с рейтингом 'M' (17+) и 'Е' (без ограничений). Реже для 'E10+' и 'T'.
#     - В Японии все иначе. Большинство игр покупают для детей и подростков (категории 'E' и 'T'). Игры для взрослой ктаегории покупаются реже. Доля 'E10+' небольшая, аналогично Америке и Европе.
# - Шаг 5
#     - 5.1.
#
#         - Полученные данные не противоречат гипотезе H0: - "Средняя пользовательская оценка игр на платформе Xbox One равна средней пользовательской оценке игр на платформе PC".
#         - Нет оснований отвергать нулевую гипотезу.
#     - 5.2.
#
#         - Полученные данные не позволяют отвергнуть нулевую гипотезу "Средняя пользовательская оценка жанра Action равна средней пользовательской оценке жанра Sports".
#         - Значит нет оснований отвергать нулевую гипотезу в пользу проверяемой нами альтернативной гипотезы "Средняя пользовательская оценка жанра Action не равна средней пользовательской оценке жанра Sports".

# %% [markdown]
# ## check

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит поправить итоговый вывод после восстановления выборки

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Итоговый вывод технически составлен грамотно
#
# стоит перепроверить результаты после определения актуального периода и исправления всех комментариев, можно обновить названия самых актуальных платформ, жанров и рейтингов, какую долю они занимают на исследуемых рынках  (а то маркетологи запутаются, что им рекламировать)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделано! Много поисправлял, пожалуйста, прошу зачесть проект, потому что горит дедлайн!!! Сказали, чтобы сегодня было зачтено! Я некоторые места с несерьезными ошибками не успеваю сделать, расскажите пожалуйста решениe 😓

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Ты выполнил практически все пункты проекта, молодец! Проведен значительный объем исследования
#
# Критические ❌ комментарии связаны с неточностями:
#
#  + заполнение пропусков в колонке год выпуска
#  + обработать пропуски и сократить категории в рейтингах ESRB — на твое усмотрение
#  + самое важное — переопределить актуальный период
#  + исправить диаграмму размаха для анализа продаж на актуальных платформах
#  + перестроить графики в ТОП-5
#  + в разделе проверки гипотез подправить выборки, выводы, Н0 и Н1, алгоритм проверки, плюс можно более подробно расшифровать значение p_value
#  + перепроверить промежуточные и итоговый выводы после всех исправлений
#
# Стоит обратить внимание на ⚠️ комментарии...
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Может пригодиться
#
# [Подборка статей о работе с библиотеками для анализа данных на языке Python](https://dfedorov.spb.ru/pandas/)
#
#
# [Визуализация](https://dfedorov.spb.ru/pandas/%D0%AD%D1%84%D1%84%D0%B5%D0%BA%D1%82%D0%B8%D0%B2%D0%BD%D0%BE%D0%B5%20%D0%B8%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20Matplotlib.html)
#
#
# [Искусство статистики](https://www.mann-ivanov-ferber.ru/books/iskusstvo-statistiki/)
#
# [Постер «Графики, которые убеждают всех»](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)
#
#
# В помощь — как реализовать интерактивный план проекта вручную (для собственных проектов), смотри по <a href="https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704">ссылке</a>
#
# пара ссылок и по разделам проекта можно будет переходить без пролистывания всего кода, особенно актуально на проектах длина которых >  10 страниц (и там где не установлен плагин TOC)

# %% [markdown]
# ## Бонус

# %%
data_games = pd.read_csv('/datasets/games.csv')

# %%
data_games.columns = map(str.lower, data_games.columns)

# %%
data_games = data_games.dropna(subset = ['year_of_release', 'name', 'genre'])

# %%
data_games['user_score'] = data_games['user_score'].replace('tbd', np.nan).astype('float')

# %%
data_games['rating'] = data_games['rating'].fillna('unknown')

# %%
data_games['total_sales'] = data_games[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %%
# check
# круги + категория другие
def graph (df, year, region, name, axes):
    
    df = df.query('year_of_release >= @year')
    
    sales = df.pivot_table(index='platform', 
                           values=region, 
                           aggfunc='sum').nlargest(5, region)
    
    sales = sales.reset_index()
    
    sales = (
            sales.append({'platform': 'Other', region: df[region].sum() 
                       - sales[region].sum()}, ignore_index= True)
         )
    
    
    sales.columns = ['platform', 'sales']
      
    labels_c=sales.platform
    colours = {'Wii':'C0', 'NES':'C1', 'GB':'C2', 'DS':'C3', 'X360':'C4', 
    'PS3':'C5', 'PS2':'C6', 'SNES':'C7', 'GBA':'C8',
               'PS4':'steelblue', '3DS':'orange', 
               'N64':'C11', 'PS':'C12', 'XB':'C13', 'PC':'C14', '2600':'C15', 'PSP':'C16', 
               'XOne':'C17',
               'WiiU':'C18', 'GC':'C19', 'GEN':'C20', 'DC':'C21', 'PSV':'C22', 
               'SAT':'C23', 'SCD':'C24', 'WS':'C25', 'NG':'C26', 
               'TG16':'C27', '3DO':'C28', 'GG':'C29', 'PCFX':'C30', 'Other':'darkred'}
   
    sales.plot(kind='pie',
               y="sales",
               
               autopct='%1.0f%%',
               wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
               textprops={'size': 'x-large'}, 
               labels= labels_c,
               colors=[colours[key] for key in labels_c],
               legend=False, 
               title = f"Популярность платформ в {name} ", 
               ax = axes).set(ylabel='')
    
    plt.tight_layout()

# %%
# check
# круги в ряд

x_year = 2010

fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle(f'Обзор рынка платформ (портрет покупателя) с {x_year} г.', fontsize = 24, fontweight='bold')

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Оптимальный период для исследования 2014-2016 гг., т.к. данные за 2016 г. неполные

# %%
# check
# круги в ряд

x_year = 2014

fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle(f'Обзор рынка платформ (портрет покупателя) с {x_year} г.', fontsize = 24, fontweight='bold')

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> 2015 год взят для акцентирования на изменении доли в продажах современных платформ

# %%
# check
# круги в ряд

x_year = 2015

fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle(f'Обзор рынка платформ (портрет покупателя) с {x_year} г.', fontsize = 24, fontweight='bold')

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])
