# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Привет, меня зовут Александр Куимов. Я буду ревьюером твоего проекта. Ты можешь обращаться ко мне на "ты"😏 Надеюсь, тебя также не смутит, если я буду обращаться к тебе на "ты", но если это неудобно, обязательно скажи об этом!
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь реагировать на мои комментарии своими по шаблону, показанному чуть ниже. Это нужно, чтобы не создавалась путаница😉
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
#
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> В такой цветовой ячейке я прошу тебя оставлять свои комментарии. Если исправляешь проект на второй итерации и выше, не забывай пожалуйста указывать номер итерации, например, "Комментарий студента v.2".
# </div>
#
# <br/>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе датасаентистом. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка" data-toc-modified-id="Подготовка-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных-и-предобработка" data-toc-modified-id="Загрузка-данных-и-предобработка-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка данных и предобработка</a></span></li><li><span><a href="#Ресемплинг-и-добавление-столбцов" data-toc-modified-id="Ресемплинг-и-добавление-столбцов-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Ресемплинг и добавление столбцов</a></span></li></ul></li><li><span><a href="#Анализ" data-toc-modified-id="Анализ-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ</a></span></li><li><span><a href="#Обучение" data-toc-modified-id="Обучение-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обучение</a></span><ul class="toc-item"><li><span><a href="#Прогнозирование-предыдущим-значением-ряда" data-toc-modified-id="Прогнозирование-предыдущим-значением-ряда-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Прогнозирование предыдущим значением ряда</a></span></li><li><span><a href="#Разделение-на-обучающую-и-тестовую-выборки." data-toc-modified-id="Разделение-на-обучающую-и-тестовую-выборки.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Разделение на обучающую и тестовую выборки.</a></span></li><li><span><a href="#Линейная-регрессия" data-toc-modified-id="Линейная-регрессия-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Линейная регрессия</a></span></li><li><span><a href="#LGBM" data-toc-modified-id="LGBM-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>LGBM</a></span></li><li><span><a href="#CatBoost" data-toc-modified-id="CatBoost-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>CatBoost</a></span></li></ul></li><li><span><a href="#Тестирование" data-toc-modified-id="Тестирование-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование</a></span></li><li><span><a href="#Общий-вывод:" data-toc-modified-id="Общий-вывод:-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод:</a></span></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# #  Прогнозирование заказов такси

# %% [markdown]
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час. Постройте модель для такого предсказания.
#
# Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.
#
# Вам нужно:
#
# 1. Загрузить данные и выполнить их ресемплирование по одному часу.
# 2. Проанализировать данные.
# 3. Обучить разные модели с различными гиперпараметрами. Сделать тестовую выборку размером 10% от исходных данных.
# 4. Проверить данные на тестовой выборке и сделать выводы.
#
#
# Данные лежат в файле `taxi.csv`. Количество заказов находится в столбце `num_orders` (от англ. *number of orders*, «число заказов»).

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Вижу твое добавленное описание проекта. Молодец! Это поможет тебе расставлять акценты в выводах

# %% [markdown]
# ## Подготовка

# %% [markdown]
# ### Загрузка данных и предобработка

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, TimeSeriesSplit
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error 
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import make_scorer
import warnings

warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('/datasets/taxi.csv', index_col=[0], parse_dates=[0])
data.head()
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32

# %%
data.sort_index(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB

# %%
data.describe()
# Out:
#          num_orders
# count  26496.000000
# mean      14.070463
# std        9.211330
# min        0.000000
# 25%        8.000000
# 50%       13.000000
# 75%       19.000000
# max      119.000000

# %%
data.isna().sum()
# Out:
# num_orders    0
# dtype: int64

# %%
data.reset_index().duplicated().sum()
# Out:
# 0

# %%
print(data.index.min(), ':', data.index.max())
# Out:
# 2018-03-01 00:00:00 : 2018-08-31 23:50:00

# %% [markdown]
# ### Ресемплинг и добавление столбцов

# %%
data = data.resample('1H').sum()

# %%
def make_features(data, max_lag, rolling_mean_size):
    data_new = data.copy()
    data_new['month'] = data.index.month
    data_new['day'] = data.index.day
    data_new['hour'] = data.index.hour
    data_new['dayofweek'] = data.index.dayofweek
    
    for lag in range(1, max_lag + 1):
        data_new[f'lag_{lag}'] = data['num_orders'].shift(lag)

    # < напишите код здесь >
    data_new['rolling_mean'] = data['num_orders'].shift(1).rolling(rolling_mean_size).mean()
    return data_new

data_new = make_features(data, 24, 7)

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Отлично, что написана функция, которая возвращает новый датафрейм, а не изменяет глобальную переменную

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
#
# Метрика на тесте должна быть ниже 48, поэтому стоит попробовать задать параметр max_lag равным 24 при создании новых признаков функцией. В случае заказов такси самая очевидная сезонность - внутри суток, а в сутках 24 часа, это значение и будет оптимальным

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Принял. Исправил.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# **Выводы:**
# 1. Данные успешно загружены, дата сделана индексом
# 2. Дубликатов и пропусков нет
# 3. Сделан ресемплинг по 1 часу
# 4. Добавлены новые признаки

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# С данными познакомились, проведен первичный аналитический осмотр!) Отлично, что проведено ресемплирование с использованием суммы. Полученная информация поможет нам в дальнейшем с предобработкой данных

# %% [markdown]
# ## Анализ

# %%
sns.lineplot(data=data_new.groupby('month')['num_orders'].sum());
plt.show()
sns.lineplot(data=data_new.groupby('day')['num_orders'].sum())
plt.show()
sns.lineplot(data=data_new.groupby('hour')['num_orders'].sum())
plt.show()
sns.lineplot(data=data_new.groupby('dayofweek')['num_orders'].sum())
plt.show()

# %%
decomposed = seasonal_decompose(data)

# %%
plt.figure(figsize=(16,10))
decomposed.trend.plot(ax=plt.gca());

# %%
plt.figure(figsize=(16,10))
decomposed.resid.plot(ax=plt.gca());

# %% [markdown]
# Посмотрим сезонность на подотрезке:

# %%
plt.figure(figsize=(16,10))
seasonal_decompose(data).seasonal['2018-07-31':'2018-08-31'].plot();

# %% [markdown]
# **Выводы:**
# 1. С каждым месяцом количество заказов только растет, в августе максимум. На графике тренда это тоже видно.
# 2. Пик заказов приходится на полночь
# 3. К концу месяца заказов больше всего
# 4. В пятницу больше всего заказов
# 5. Ряд стационарный, так как распределение не меняется со временем

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
#
# Желательно сначала провести декомпозицию всего ряда (изучить сезонность, тренд), а затем взять подотрезок: `seasonal_decompose(data).seasonal['2018-07-31':'2018-08-31']` (изучить сезонность)

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Принял. Исправил.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# ## Обучение

# %% [markdown]
# ### Прогнозирование предыдущим значением ряда

# %%
train_base, test_base = train_test_split(data, shuffle=False, test_size=0.1)
train_base = train_base.dropna()
prediction = test_base.shift(1)
prediction.iloc[0] = train_base.iloc[-1]
print("RMSE модели по прошлым данным", mean_squared_error(test_base, prediction, squared=False))
# Out:
# RMSE модели по прошлым данным 58.856486242815066

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Хорошо, что деление происходит последовательно по времени

# %% [markdown]
# ### Разделение на обучающую и тестовую выборки.

# %%
train, test = train_test_split(data_new, shuffle=False, test_size=0.1)
train = train.dropna()
train_features = train.drop(['num_orders'], axis=1)
train_target = train['num_orders']

test_features = test.drop(['num_orders'], axis=1)
test_target = test['num_orders']

# %% [markdown]
# ### Линейная регрессия

# %%
state = 12345

# %%
# %%time
lg_model = LinearRegression()
tss = TimeSeriesSplit(n_splits = 5)
cross_val_score(lg_model, train_features, train_target, cv=tss, scoring='neg_root_mean_squared_error').mean()*(-1)
# Out:
# CPU times: user 502 ms, sys: 668 ms, total: 1.17 s
# Wall time: 1.07 s
# 26.941466127371836

# %% [markdown]
# ### LGBM

# %% [markdown]
# Базовых гиперпараметров достаточно для решения задачи.

# %%
# %%time
lgbm_model = LGBMRegressor(n_jobs=-1, random_state=state)
parameters = {'num_iterations': [100, 150], 'max_depth': [12, 15]}
gridsearch_model = GridSearchCV(n_jobs=-1, cv=tss, estimator=lgbm_model, param_grid=parameters,
                                scoring='neg_root_mean_squared_error')
gridsearch_model.fit(train_features, train_target)
display(gridsearch_model.best_params_)
display(gridsearch_model.best_score_)
display(gridsearch_model.cv_results_)
# Out:
# {'max_depth': 15, 'num_iterations': 100}
# -24.89529006335699
# {'mean_fit_time': array([0.99262137, 1.49162908, 1.53979707, 1.95613589]),
#  'std_fit_time': array([0.21230701, 0.41236844, 0.83533554, 0.88816778]),
#  'mean_score_time': array([0.02122817, 0.00570922, 0.02325664, 0.04172587]),
#  'std_score_time': array([0.03414641, 0.00298327, 0.03465279, 0.0429495 ]),
#  'param_max_depth': masked_array(data=[12, 12, 15, 15],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_num_iterations': masked_array(data=[100, 150, 100, 150],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_depth': 12, 'num_iterations': 100},
#   {'max_depth': 12, 'num_iterations': 150},
#   {'max_depth': 15, 'num_iterations': 100},
#   {'max_depth': 15, 'num_iterations': 150}],
#  'split0_test_score': array([-22.67414294, -22.77980739, -22.49066851, -22.63475914]),
# ...

# %% [markdown]
# ### CatBoost

# %% [markdown]
# Базовых гиперпараметров достаточно для решения задачи.

# %%
# %%time
parameters = {'learning_rate': [0.03, 0.06],
        'depth': [6, 9]}
cat_model = CatBoostRegressor(random_state=state, logging_level='Silent')
gridsearch_model_cat = GridSearchCV(n_jobs=-1, cv=tss, estimator=cat_model, param_grid=parameters,
                                    scoring='neg_root_mean_squared_error')
gridsearch_model_cat.fit(train_features, train_target)
display(gridsearch_model_cat.best_params_)
display(gridsearch_model_cat.best_score_)
display(gridsearch_model_cat.cv_results_)
# Out:
# {'depth': 6, 'learning_rate': 0.03}
# -22.78398908000412
# {'mean_fit_time': array([ 7.04365473,  6.98773713, 37.54017687, 37.83419294]),
#  'std_fit_time': array([0.27223208, 0.32673942, 2.17438467, 1.82372707]),
#  'mean_score_time': array([0.00373836, 0.00396357, 0.00702477, 0.00631509]),
#  'std_score_time': array([0.0001363 , 0.00061388, 0.00122179, 0.0001406 ]),
#  'param_depth': masked_array(data=[6, 6, 9, 9],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_learning_rate': masked_array(data=[0.03, 0.06, 0.03, 0.06],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'depth': 6, 'learning_rate': 0.03},
#   {'depth': 6, 'learning_rate': 0.06},
#   {'depth': 9, 'learning_rate': 0.03},
#   {'depth': 9, 'learning_rate': 0.06}],
#  'split0_test_score': array([-19.08134558, -19.43845023, -19.0339154 , -19.54060635]),
# ...

# %% [markdown]
# **CatBoost модель показала лучшую метрику. Проверим на ней данные на тестовой выборке**

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# При построении и поиске лучшей модели следует использовать один из предложенных вариантов:
#
# 1. Подбор гиперпараметров на валидационной выборке;
#
# 2. ИЛИ применение кросс-валидации  `grid.best_score_` - в этом случае не следует проверять модель на тесте. Это значит, что вместо обычного fit-predict следует использовать GridSearchCV или cross_val_score если у модели гиперпараметры не подбираются), использовать атрибут `.best_score_` (или `cross_val_score(..).mean() если у модели гиперпараметры не подбираются)` для вывода метрики. На всякий случай предупрежу, что при работе с временными рядами не следует использовать стандартную кросс-валидацию, так как в определенный момент тренировочная выборка окажется позже валидационной. Для решения этой проблемы стоит использовать <a href="https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.TimeSeriesSplit.html">TimeSeriesSplit</a>. Объект этого типа нужно передать в параметр cv в метод основанный на кросс-валидации. Следует использовать метрику `neg_root_mean_squared_error`. Подать ее нужно внутрь `cross_val_score` и/или `SearchCV`, используя скорер `scoring=...`.  (это все касается каждого из экземпляров `cross_val_score` и/или `SearchCV`)

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Следует использовать больше одного набора гиперпараметров хотя бы для одной модели, к примеру, перебирать как `max_depth`, так и `min_samples_leaf`. Напомню, что эти наборы следует еще и перебирать. Исправь, пожалуйста

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Принял. Исправил.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# ## Тестирование

# %%
# %%time
cat_model = CatBoostRegressor(depth=6, learning_rate=0.03, random_state=state, logging_level='Silent')
cat_model.fit(train_features, train_target)
prediction_cat = cat_model.predict(test_features)
print('RMSE CatBoost Test sample:', mean_squared_error(test_target, prediction_cat, squared=False))
# Out:
# RMSE CatBoost Test sample: 40.6278049712041
# CPU times: user 6.42 s, sys: 125 ms, total: 6.54 s
# Wall time: 8.81 s

# %% [markdown]
# Для наглядности можно нарисовать график, отображающий предсказанный временной ряд относительно исходного

# %%
fig, ax = plt.subplots(figsize=(16, 8))
data_ax = pd.Series(prediction_cat, index = test_target.index)
ax.plot(data_ax, label='График предсказанных рядов')
ax.plot(test_target, label='График исходного ряда')
legend = ax.legend(fontsize= 12)

# %% [markdown]
# **Выводы:**
# - Модель CatBoost успешно справилась с задачей: RMSE 40.6
# - На графике видно, что модель хорошо предсказывает всё, кроме пиковых значений, т.к. они выбиваются из заданной логики.

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Отлично, что  визуализированы результаты, показаны предсказанные значения лучшей модели и реальные тестовые

# %% [markdown]
# ## Общий вывод:

# %% [markdown]
# - Данные успешно загружены и предобработаны
# - Произведен ресемплинг данных по одному часу и добавлены соответствующие столбцы: месяц, день, час, день недели, отстающие значения, скользящее среднее
# - С каждым месяцом количество заказов только растет, в августе максимум. На графике тренда это тоже видно.
# - Пик заказов приходится на полночь по времени и пятницу по дню недели
# - Ряд стационарный, так как распределение не меняется со временем
# - Лучшей моделью оказалась CatBoost
# - Успешно спрогнозированы данные на август: RMSE 43.3 < 48
# - Модель хорошо прогнозирует тенденции, но плохо распознает пиковые значения.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера <a class="tocSkip"> </h2>
#
#
# У меня сложилось хорошее общее впечатление о проекте, тебе удалось неплохо справиться с этим проектом. Молодец! Подготовлены данные для анализа, изучен каждый параметр. Все красиво визуализировано, построено несколько моделей регрессии и оценено их качество. Осмысленная аналитика и дельная модельная работа - многое удалось как надо)
#
# Отмечу отдельные положительные моменты проекта🙂:
#
# - в ходе проекта встречались  функции, помогающие избавиться от дублирования кода;
# - много красивых визуализаций в проекте и хорошая интерпретация;
# - при обучении моделей использована валидация и поиск гиперпараметров.
#
# Есть несколько моментов всего, на которые стоит ещё раз взглянуть, я указал их в моих комментариях по ходу проекта. Предлагаю тебе доработать проект по моим комментариям, чтобы довести его до совершенства.
#
#
#
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
#
#
# Теперь почти идеально. Принимаю работу)
#
# Если хочешь лучше разобраться в теме, то могу посоветовать тебе:
#
# Полезная лекция про временные ряды: https://www.youtube.com/watch?v=u433nrxdf5k
#
# Б.Б. Демешев - временные ряды https://disk.yandex.ru/i/LiDHB-B3A6Lz5A
#
# Базовое применение ARIMA - https://colab.research.google.com/drive/17RnG91Eq8JBKyxToNzvCvjibfxum-oPj?usp=sharing
#
# Канторович - Анализ временных рядов https://yadi.sk/i/IOkUOS3hTXf3gg
# https://facebook.github.io/prophet/
#
# https://facebook.github.io/prophet/docs/quick_start.html#python-api
#
# https://nbviewer.jupyter.org/github/miptgirl/habra_materials/blob/master/prophet/habra_data.ipynb
#
#
#
# В этом проекте были отработаны все моменты.
#
# Успехов тебе в следующем спринте!
#
# Рад был помочь тебе)
#
# </div>

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Данные загружены и подготовлены
# - [x]  Данные проанализированы
# - [x]  Модель обучена, гиперпараметры подобраны
# - [x]  Качество моделей проверено, выводы сделаны
# - [x]  Значение *RMSE* на тестовой выборке не больше 48
